# %%
# !nvidia-smi
# Out:
# Mon Apr 11 18:05:38 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch
if torch.cuda.is_available():
    print('Yes')
else:
  print("NO")
# Out:
# Yes

# %%
from torch.optim import lr_scheduler
import os
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import pandas as pd 
import numpy as np
import pandas as pd
import os
import torchvision
import torch.utils.data as utils
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torchvision.utils

# %%
train_dir="/content/sign_data/train"
train_csv="/content/sign_data/train_data.csv"
test_dir="/content/sign_data/test"
test_csv="/content/sign_data/test_data.csv"

# %%
df_train=pd.read_csv(train_csv)
df_train.head() #get first 5 rows.
# Out:
#    068/09_068.png  068_forg/03_0113068.PNG  1
# 0  068/09_068.png  068_forg/01_0124068.PNG  1
# 1  068/09_068.png  068_forg/02_0124068.PNG  1
# 2  068/09_068.png  068_forg/01_0113068.PNG  1
# 3  068/09_068.png  068_forg/04_0124068.PNG  1
# 4  068/09_068.png  068_forg/04_0113068.PNG  1

# %%
df_test = pd.read_csv(test_csv)
df_test.head()
# Out:
#    068/09_068.png  068_forg/03_0113068.PNG  1
# 0  068/09_068.png  068_forg/01_0124068.PNG  1
# 1  068/09_068.png  068_forg/02_0124068.PNG  1
# 2  068/09_068.png  068_forg/01_0113068.PNG  1
# 3  068/09_068.png  068_forg/04_0124068.PNG  1
# 4  068/09_068.png  068_forg/04_0113068.PNG  1

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
class SiameseNetworkDataset():
    
    def __init__(self,training_csv=None,training_dir=None,transform=None):
        # used to prepare the labels and images path
        self.training_df=pd.read_csv(training_csv)
        self.training_df.columns =["image1","image2","label"]
        self.training_dir = training_dir    
        self.transform = transform

    def __getitem__(self,index):
        
        # getting the image path
        image1_path=os.path.join(self.training_dir,self.training_df.iat[index,0])
        image2_path=os.path.join(self.training_dir,self.training_df.iat[index,1])
        
        
        # Loading the image
        img0 = Image.open(image1_path)
        img1 = Image.open(image2_path)
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        # Apply image transformations
        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(self.training_df.iat[index,2])],dtype=np.float32))
    
    def __len__(self):
        return len(self.training_df)

# %%
import torchvision.transforms as transforms

siamese_dataset = SiameseNetworkDataset(train_csv,train_dir,
                                        transform=transforms.Compose([transforms.Resize((105,105)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       )

# %%
import torch.nn as nn


class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        
        # Setting up the Sequential of CNN Layers
        self.cnn1 = nn.Sequential(
            
            nn.Conv2d(1, 96, kernel_size=11,stride=1),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(5,alpha=0.0001,beta=0.75,k=2),
            nn.MaxPool2d(3, stride=2),
            
            nn.Conv2d(96, 256, kernel_size=5,stride=1,padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(5,alpha=0.0001,beta=0.75,k=2),
            nn.MaxPool2d(3, stride=2),
            nn.Dropout2d(p=0.3),

            nn.Conv2d(256,384 , kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384,256 , kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(3, stride=2),
            nn.Dropout2d(p=0.3),

        )
        
        # Defining the fully connected layers
        self.fc1 = nn.Sequential(
            nn.Linear(30976, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout2d(p=0.5),
            
            nn.Linear(1024, 128),
            nn.ReLU(inplace=True),
            
            nn.Linear(128,2))
        
  
  
    def forward_once(self, x):
        # Forward pass 
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        # forward pass of input 1
        output1 = self.forward_once(input1)
        # forward pass of input 2
        output2 = self.forward_once(input2)
        return output1, output2

# %%
class Config():
    training_dir = "../input/sign_data/sign_data/train"
    testing_dir = "../input/sign_data/sign_data/test"
    train_batch_size = 32
    train_number_epochs = 20

# %%
from torch.utils.data import DataLoader,Dataset
test_dataset = SiameseNetworkDataset(training_csv=test_csv,training_dir=test_dir,
                                        transform=transforms.Compose([transforms.Resize((105,105)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       )

test_dataloader = DataLoader(test_dataset,num_workers=6,batch_size=1,shuffle=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.RMSprop(net.parameters(), lr=1e-4, alpha=0.99, eps=1e-8, weight_decay=0.0005, momentum=0.9)

# %%
def train():
    counter = []
    loss_history = [] 
    iteration_number= 0
    
    for epoch in range(0,Config.train_number_epochs):
        for i, data in enumerate(train_dataloader,0):
            img0, img1 , label = data
            img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
            optimizer.zero_grad()
            output1,output2 = net(img0,img1)
            loss_contrastive = criterion(output1,output2,label)
            loss_contrastive.backward()
            optimizer.step()
            if i %50 == 0 :
                print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
                iteration_number +=10
                counter.append(iteration_number)
                loss_history.append(loss_contrastive.item())
    return net
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Train the model
model = train()
torch.save(model.state_dict(), "model.pt")
print("Model Saved Successfully")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch number 0
#  Current loss 1.869611382484436
#
# Epoch number 0
#  Current loss 1.6709847450256348
#
# Epoch number 0
#  Current loss 1.2513489723205566
#
# Epoch number 0
#  Current loss 1.4345035552978516
#
# Epoch number 0
#  Current loss 1.3439993858337402
#
# Epoch number 0
#  Current loss 1.1985218524932861
#
# Epoch number 0
#  Current loss 1.2611316442489624
#
# Epoch number 0
#  Current loss 1.1805083751678467
#
# Epoch number 0
#  Current loss 1.1737127304077148
#
# Epoch number 0
#  Current loss 1.1809675693511963
#
# Epoch number 0
#  Current loss 1.212613821029663
#
# Epoch number 0
#  Current loss 1.1999242305755615
#
# Epoch number 0
#  Current loss 1.221345067024231
#
# Epoch number 0
#  Current loss 1.4988634586334229
#
# Epoch number 0
#  Current loss 1.3535921573638916
#
# Epoch number 1
#  Current loss 1.3019168376922607
#
# Epoch number 1
#  Current loss 1.1830189228057861
#
# Epoch number 1
#  Current loss 1.254875659942627
#
# Epoch number 1
#  Current loss 1.2257531881332397
#
# Epoch number 1
#  Current loss 1.0874344110488892
#
# Epoch number 1
#  Current loss 1.177819013595581
#
# Epoch number 1
#  Current loss 1.3037004470825195
#
# Epoch number 1
#  Current loss 1.2206988334655762
#
# Epoch number 1
#  Current loss 1.1948726177215576
#
# Epoch number 1
#  Current loss 1.4258091449737549
#
# Epoch number 1
#  Current loss 1.294478178024292
#
# Epoch number 1
#  Current loss 1.2430800199508667
#
# Epoch number 1
#  Current loss 1.2036149501800537
#
# Epoch number 1
#  Current loss 1.109255313873291
#
# Epoch number 1
#  Current loss 1.267216682434082
#
# Epoch number 2
#  Current loss 1.182860016822815
#
# Epoch number 2
#  Current loss 1.2392661571502686
#
# Epoch number 2
#  Current loss 1.0925984382629395
#
# Epoch number 2
#  Current loss 1.2071001529693604
#
# Epoch number 2
#  Current loss 1.1526782512664795
#
# Epoch number 2
#  Current loss 1.2543184757232666
#
# Epoch number 2
#  Current loss 1.1372747421264648
#
# Epoch number 2
#  Current loss 1.3497973680496216
#
# Epoch number 2
#  Current loss 1.34724760055542
#
# Epoch number 2
#  Current loss 1.171558141708374
#
# Epoch number 2
#  Current loss 1.091442346572876
#
# Epoch number 2
#  Current loss 1.0112087726593018
#
# Epoch number 2
#  Current loss 1.3229371309280396
#
# Epoch number 2
#  Current loss 1.5589112043380737
#
# Epoch number 2
#  Current loss 1.1090167760849
#
# Epoch number 3
#  Current loss 1.1208207607269287
#
# Epoch number 3
#  Current loss 1.7021186351776123
#
# Epoch number 3
#  Current loss 1.1931443214416504
#
# Epoch number 3
#  Current loss 1.200728178024292
#
# Epoch number 3
#  Current loss 1.1934354305267334
#
# Epoch number 3
#  Current loss 0.9018316268920898
#
# Epoch number 3
#  Current loss 1.390685796737671
#
# Epoch number 3
#  Current loss 1.1151347160339355
#
# Epoch number 3
#  Current loss 0.9987389445304871
#
# Epoch number 3
#  Current loss 1.1032452583312988
#
# Epoch number 3
#  Current loss 1.0224390029907227
#
# Epoch number 3
#  Current loss 1.981634497642517
#
# Epoch number 3
#  Current loss 1.1162992715835571
#
# Epoch number 3
#  Current loss 1.147871971130371
#
# Epoch number 3
#  Current loss 1.293188452720642
#
# Epoch number 4
#  Current loss 1.2498984336853027
#
# Epoch number 4
#  Current loss 1.0671768188476562
#
# Epoch number 4
#  Current loss 1.3660123348236084
#
# Epoch number 4
#  Current loss 1.323878288269043
#
# Epoch number 4
#  Current loss 1.3480377197265625
#
# Epoch number 4
#  Current loss 1.1470346450805664
#
# Epoch number 4
#  Current loss 1.090061902999878
#
# Epoch number 4
#  Current loss 1.3220430612564087
#
# Epoch number 4
#  Current loss 1.1742185354232788
#
# Epoch number 4
#  Current loss 1.3311142921447754
#
# Epoch number 4
#  Current loss 1.1027390956878662
#
# Epoch number 4
#  Current loss 1.4907819032669067
#
# Epoch number 4
#  Current loss 1.4671655893325806
#
# Epoch number 4
#  Current loss 1.2263731956481934
#
# Epoch number 4
#  Current loss 1.226719617843628
#
# Epoch number 5
#  Current loss 1.0714986324310303
#
# Epoch number 5
#  Current loss 1.2138195037841797
#
# Epoch number 5
#  Current loss 1.2284107208251953
#
# Epoch number 5
#  Current loss 1.156833291053772
#
# Epoch number 5
#  Current loss 1.2676301002502441
#
# Epoch number 5
#  Current loss 0.9941377639770508
#
# Epoch number 5
#  Current loss 1.7388429641723633
#
# Epoch number 5
#  Current loss 0.9980751872062683
#
# Epoch number 5
#  Current loss 1.198885440826416
#
# Epoch number 5
#  Current loss 1.175351619720459
#
# Epoch number 5
#  Current loss 1.1208207607269287
#
# Epoch number 5
#  Current loss 1.2790043354034424
#
# Epoch number 5
#  Current loss 1.0771180391311646
#
# Epoch number 5
#  Current loss 1.1509459018707275
#
# Epoch number 5
#  Current loss 1.1875869035720825
#
# Epoch number 6
#  Current loss 1.0962955951690674
#
# Epoch number 6
#  Current loss 1.2387595176696777
#
# Epoch number 6
#  Current loss 1.340989589691162
#
# Epoch number 6
#  Current loss 1.1089500188827515
#
# Epoch number 6
#  Current loss 0.9154664278030396
#
# Epoch number 6
#  Current loss 1.2872095108032227
#
# Epoch number 6
#  Current loss 1.2960509061813354
#
# Epoch number 6
#  Current loss 1.2697298526763916
#
# Epoch number 6
#  Current loss 1.241847276687622
#
# Epoch number 6
#  Current loss 1.2149114608764648
#
# Epoch number 6
#  Current loss 1.1691677570343018
#
# Epoch number 6
#  Current loss 1.0922927856445312
#
# Epoch number 6
#  Current loss 1.1297268867492676
#
# Epoch number 6
#  Current loss 1.3669419288635254
#
# Epoch number 6
#  Current loss 1.004819631576538
#
# Epoch number 7
#  Current loss 1.272050142288208
#
# Epoch number 7
#  Current loss 1.1943559646606445
#
# Epoch number 7
#  Current loss 1.1081000566482544
#
# Epoch number 7
#  Current loss 1.2929574251174927
#
# Epoch number 7
#  Current loss 1.3187406063079834
#
# Epoch number 7
#  Current loss 1.2593743801116943
#
# Epoch number 7
#  Current loss 1.1418288946151733
#
# Epoch number 7
#  Current loss 1.16771399974823
#
# Epoch number 7
#  Current loss 1.1240031719207764
#
# Epoch number 7
#  Current loss 1.1272506713867188
#
# Epoch number 7
#  Current loss 1.2915798425674438
#
# Epoch number 7
#  Current loss 1.2024335861206055
#
# Epoch number 7
#  Current loss 1.379608154296875
#
# Epoch number 7
#  Current loss 1.8549487590789795
#
# Epoch number 7
#  Current loss 1.161965250968933
#
# Epoch number 8
#  Current loss 1.2318437099456787
#
# Epoch number 8
#  Current loss 1.1667940616607666
#
# Epoch number 8
#  Current loss 1.4773310422897339
#
# Epoch number 8
#  Current loss 1.3224976062774658
#
# Epoch number 8
#  Current loss 1.3455750942230225
#
# Epoch number 8
#  Current loss 1.4203799962997437
#
# Epoch number 8
#  Current loss 1.119741678237915
#
# Epoch number 8
#  Current loss 1.149085283279419
#
# Epoch number 8
#  Current loss 1.298034906387329
#
# Epoch number 8
#  Current loss 0.9948564767837524
#
# Epoch number 8
#  Current loss 1.4622873067855835
#
# Epoch number 8
#  Current loss 1.2565052509307861
#
# Epoch number 8
#  Current loss 1.32124662399292
#
# Epoch number 8
#  Current loss 1.1794793605804443
#
# Epoch number 8
#  Current loss 1.1902847290039062
#
# Epoch number 9
#  Current loss 1.2159521579742432
#
# Epoch number 9
#  Current loss 1.208899974822998
#
# Epoch number 9
#  Current loss 1.2089320421218872
#
# Epoch number 9
#  Current loss 1.225999116897583
#
# Epoch number 9
#  Current loss 1.4322998523712158
#
# Epoch number 9
#  Current loss 1.0083012580871582
#
# Epoch number 9
#  Current loss 1.2319767475128174
#
# Epoch number 9
#  Current loss 1.21535062789917
#
# Epoch number 9
#  Current loss 1.3674349784851074
#
# Epoch number 9
#  Current loss 1.355080246925354
#
# Epoch number 9
#  Current loss 1.043195366859436
#
# Epoch number 9
#  Current loss 1.1461987495422363
#
# Epoch number 9
#  Current loss 1.2199835777282715
#
# Epoch number 9
#  Current loss 1.0683441162109375
#
# Epoch number 9
#  Current loss 1.1645818948745728
#
# Epoch number 10
#  Current loss 1.1898329257965088
#
# Epoch number 10
#  Current loss 1.3146514892578125
#
# Epoch number 10
#  Current loss 1.323164463043213
#
# Epoch number 10
#  Current loss 1.4083800315856934
#
# Epoch number 10
#  Current loss 1.4658403396606445
#
# Epoch number 10
#  Current loss 1.5867083072662354
#
# Epoch number 10
#  Current loss 1.0732437372207642
#
# Epoch number 10
#  Current loss 1.1185550689697266
#
# Epoch number 10
#  Current loss 1.3729597330093384
#
# Epoch number 10
#  Current loss 1.0312855243682861
#
# Epoch number 10
#  Current loss 1.1082894802093506
#
# Epoch number 10
#  Current loss 1.2311594486236572
#
# Epoch number 10
#  Current loss 1.406510353088379
#
# Epoch number 10
#  Current loss 1.0732120275497437
#
# Epoch number 10
#  Current loss 1.1678481101989746
#
# Epoch number 11
#  Current loss 1.0848418474197388
#
# Epoch number 11
#  Current loss 0.9935647249221802
#
# Epoch number 11
#  Current loss 1.164712905883789
#
# Epoch number 11
#  Current loss 1.036182165145874
#
# Epoch number 11
#  Current loss 1.0937086343765259
#
# Epoch number 11
#  Current loss 1.4151663780212402
#
# Epoch number 11
#  Current loss 1.1202104091644287
#
# Epoch number 11
#  Current loss 1.0471818447113037
#
# Epoch number 11
#  Current loss 1.2923396825790405
#
# Epoch number 11
#  Current loss 1.1857088804244995
#
# Epoch number 11
#  Current loss 1.045976161956787
#
# Epoch number 11
#  Current loss 1.3552348613739014
#
# Epoch number 11
#  Current loss 1.0368638038635254
#
# Epoch number 11
#  Current loss 1.1357412338256836
#
# Epoch number 11
#  Current loss 1.2465121746063232
#
# Epoch number 12
#  Current loss 1.0953701734542847
#
# Epoch number 12
#  Current loss 1.3247406482696533
#
# Epoch number 12
#  Current loss 1.252915859222412
#
# Epoch number 12
#  Current loss 1.2978991270065308
#
# Epoch number 12
#  Current loss 1.1357375383377075
#
# Epoch number 12
#  Current loss 1.4506633281707764
#
# Epoch number 12
#  Current loss 1.2551000118255615
#
# Epoch number 12
#  Current loss 1.213244080543518
#
# Epoch number 12
#  Current loss 1.4405573606491089
#
# Epoch number 12
#  Current loss 1.0543553829193115
#
# Epoch number 12
#  Current loss 1.1871258020401
#
# Epoch number 12
#  Current loss 1.2176554203033447
#
# Epoch number 12
#  Current loss 1.5033644437789917
#
# Epoch number 12
#  Current loss 1.1198887825012207
#
# Epoch number 12
#  Current loss 1.3407535552978516
#
# Epoch number 13
#  Current loss 1.0891900062561035
#
# Epoch number 13
#  Current loss 1.328045129776001
#
# Epoch number 13
#  Current loss 1.194990634918213
#
# Epoch number 13
#  Current loss 1.092971920967102
#
# Epoch number 13
#  Current loss 1.3550304174423218
#
# Epoch number 13
#  Current loss 1.1825395822525024
#
# Epoch number 13
#  Current loss 1.1866036653518677
#
# Epoch number 13
#  Current loss 1.3542262315750122
#
# Epoch number 13
#  Current loss 1.0319201946258545
#
# Epoch number 13
#  Current loss 1.2370600700378418
#
# Epoch number 13
#  Current loss 1.119112253189087
#
# Epoch number 13
#  Current loss 1.2128137350082397
#
# Epoch number 13
#  Current loss 1.0450618267059326
#
# Epoch number 13
#  Current loss 1.2832045555114746
#
# Epoch number 13
#  Current loss 1.020259976387024
#
# Epoch number 14
#  Current loss 1.3657944202423096
#
# Epoch number 14
#  Current loss 1.1506110429763794
#
# Epoch number 14
#  Current loss 1.3034521341323853
#
# Epoch number 14
#  Current loss 1.013564109802246
#
# Epoch number 14
#  Current loss 1.3547840118408203
#
# Epoch number 14
#  Current loss 1.172104835510254
#
# Epoch number 14
#  Current loss 1.5862767696380615
#
# Epoch number 14
#  Current loss 1.207422137260437
#
# Epoch number 14
#  Current loss 1.0698351860046387
#
# Epoch number 14
#  Current loss 1.0686061382293701
#
# Epoch number 14
#  Current loss 1.4881043434143066
#
# Epoch number 14
#  Current loss 1.5349045991897583
#
# Epoch number 14
#  Current loss 1.1569437980651855
#
# Epoch number 14
#  Current loss 1.1912397146224976
#
# Epoch number 14
#  Current loss 1.282981514930725
#
# Epoch number 15
#  Current loss 1.2638310194015503
#
# Epoch number 15
#  Current loss 1.2428351640701294
#
# Epoch number 15
#  Current loss 1.37471604347229
#
# Epoch number 15
#  Current loss 1.1201903820037842
#
# Epoch number 15
#  Current loss 1.2714240550994873
#
# Epoch number 15
#  Current loss 1.0820844173431396
#
# Epoch number 15
#  Current loss 1.3288377523422241
#
# Epoch number 15
#  Current loss 1.2701724767684937
#
# Epoch number 15
#  Current loss 1.2583167552947998
#
# Epoch number 15
#  Current loss 1.0646617412567139
#
# Epoch number 15
#  Current loss 1.6058993339538574
#
# Epoch number 15
#  Current loss 1.142399549484253
#
# Epoch number 15
#  Current loss 1.1977837085723877
#
# Epoch number 15
#  Current loss 1.0660629272460938
#
# Epoch number 15
#  Current loss 0.8590716123580933
#
# Epoch number 16
#  Current loss 0.8750157356262207
#
# Epoch number 16
#  Current loss 0.9961024522781372
#
# Epoch number 16
#  Current loss 1.1746747493743896
#
# Epoch number 16
#  Current loss 1.2149543762207031
#
# Epoch number 16
#  Current loss 1.2194393873214722
#
# Epoch number 16
#  Current loss 1.2048439979553223
#
# Epoch number 16
#  Current loss 1.375834584236145
#
# Epoch number 16
#  Current loss 1.1225703954696655
#
# Epoch number 16
#  Current loss 1.1306102275848389
#
# Epoch number 16
#  Current loss 1.263696551322937
#
# Epoch number 16
#  Current loss 1.1778125762939453
#
# Epoch number 16
#  Current loss 1.0424158573150635
#
# Epoch number 16
#  Current loss 1.2963345050811768
#
# Epoch number 16
#  Current loss 1.1156107187271118
#
# Epoch number 16
#  Current loss 1.3239517211914062
#
# Epoch number 17
#  Current loss 1.6615679264068604
#
# Epoch number 17
#  Current loss 1.1119886636734009
#
# Epoch number 17
#  Current loss 1.2501404285430908
#
# Epoch number 17
#  Current loss 1.1732827425003052
#
# Epoch number 17
#  Current loss 1.338089942932129
#
# Epoch number 17
#  Current loss 1.262887716293335
#
# Epoch number 17
#  Current loss 1.2594844102859497
#
# Epoch number 17
#  Current loss 1.3951494693756104
#
# Epoch number 17
#  Current loss 1.3986973762512207
#
# Epoch number 17
#  Current loss 1.258124828338623
#
# Epoch number 17
#  Current loss 1.4850072860717773
#
# Epoch number 17
#  Current loss 1.0716720819473267
#
# Epoch number 17
#  Current loss 1.1612746715545654
#
# Epoch number 17
#  Current loss 1.1342074871063232
#
# Epoch number 17
#  Current loss 1.9022960662841797
#
# Epoch number 18
#  Current loss 1.0418360233306885
#
# Epoch number 18
#  Current loss 1.2837516069412231
#
# Epoch number 18
#  Current loss 1.2477185726165771
#
# Epoch number 18
#  Current loss 1.8948038816452026
#
# Epoch number 18
#  Current loss 1.1922881603240967
#
# Epoch number 18
#  Current loss 1.184664011001587
#
# Epoch number 18
#  Current loss 1.3000493049621582
#
# Epoch number 18
#  Current loss 1.2244311571121216
#
# Epoch number 18
#  Current loss 1.2934609651565552
#
# Epoch number 18
#  Current loss 1.1121840476989746
#
# Epoch number 18
#  Current loss 1.0619871616363525
#
# Epoch number 18
#  Current loss 1.1313989162445068
#
# Epoch number 18
#  Current loss 0.9500406384468079
#
# Epoch number 18
#  Current loss 1.2775061130523682
#
# Epoch number 18
#  Current loss 1.1390764713287354
#
# Epoch number 19
#  Current loss 1.2114838361740112
#
# Epoch number 19
#  Current loss 1.232102394104004
#
# Epoch number 19
#  Current loss 1.2919046878814697
#
# Epoch number 19
#  Current loss 0.9885290861129761
#
# Epoch number 19
#  Current loss 1.4130549430847168
#
# Epoch number 19
#  Current loss 1.2223236560821533
#
# Epoch number 19
#  Current loss 1.2251596450805664
#
# Epoch number 19
#  Current loss 1.1004242897033691
#
# Epoch number 19
#  Current loss 1.0652527809143066
#
# Epoch number 19
#  Current loss 1.1126940250396729
#
# Epoch number 19
#  Current loss 1.1931027173995972
#
# Epoch number 19
#  Current loss 1.2392857074737549
#
# Epoch number 19
#  Current loss 1.1320996284484863
#
# Epoch number 19
#  Current loss 1.036855936050415
#
# Epoch number 19
#  Current loss 1.2440600395202637
#
# Model Saved Successfully

# %%
import torch
from PIL import Image

counter=0
list_0 = torch.FloatTensor([[0]])
list_1 = torch.FloatTensor([[1]])
for i, data in enumerate(test_dataloader,0): 
  x0, x1 , label = data
  concatenated = torch.cat((x0,x1),0)
  output1,output2 = model(x0.to(device),x1.to(device))
  eucledian_distance = F.pairwise_distance(output1, output2)
  if label==list_0:
    label="Orginial"
  else:
    label="Forged"
  imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f} Label: {}'.format(eucledian_distance.item(),label))
  counter=counter+1
  if counter ==20:
     break
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
